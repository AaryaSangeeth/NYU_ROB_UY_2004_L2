# %%
import numpy as np
from rob2004.interface import RobotInterfaceSim

# %%
robot = RobotInterfaceSim()

# %%
robot.getJointState()
# Out:
# {'q': array([ 0.9345947 , -0.05369567, -1.47185366, -0.93459747,  0.05369603,
#          1.4718538 ,  0.9345947 , -0.05369567, -1.47185366, -0.93459747,
#          0.05369603,  1.4718538 ]),
#  'dq': array([ 0.00093154, -0.00089446, -0.0042466 , -0.00093154,  0.00089446,
#          0.0042466 ,  0.00093154, -0.00089446, -0.0042466 , -0.00093154,
#          0.00089446,  0.0042466 ])}

# %%
tau = np.zeros(12)
tau[0] = 2.0
robot.setJointCommand(tau)
